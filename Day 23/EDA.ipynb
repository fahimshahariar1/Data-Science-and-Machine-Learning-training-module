# %%
#importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading data set

data = pd.read_csv("D:/Data Science/WHO-COVID-19-global-data.csv") #change the slash to forward so that it can read
#here data is a variable name

# %%
#performing basic data engineering

data.info()
#getting basic info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57360 entries, 0 to 57359
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      57360 non-null  object
#  1   Country_code       57121 non-null  object
#  2   Country            57360 non-null  object
#  3   WHO_region         53058 non-null  object
#  4   New_cases          38869 non-null  float64
#  5   Cumulative_cases   57360 non-null  int64
#  6   New_deaths         24956 non-null  float64
#  7   Cumulative_deaths  57360 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 3.5+ MB

# %%
#showing first few rows of the dataset

data.head()
#as we have seen before that if we don't put any number inside the method it will show the first 5 values
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# 4                 0         NaN                  0

# %%
data.tail()
# Out:
#       Date_reported Country_code   Country WHO_region  New_cases  \
# 57355    2024-06-30           ZW  Zimbabwe       AFRO        6.0
# 57356    2024-07-07           ZW  Zimbabwe       AFRO        1.0
# 57357    2024-07-14           ZW  Zimbabwe       AFRO        NaN
# 57358    2024-07-21           ZW  Zimbabwe       AFRO        1.0
# 57359    2024-07-28           ZW  Zimbabwe       AFRO        NaN
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 57355            266384         NaN               5740
# 57356            266385         NaN               5740
# 57357            266385         NaN               5740
# 57358            266386         NaN               5740
# 57359            266386         NaN               5740

# %%
#checking validity

data.isnull().sum()
# Out:
# Date_reported            0
# Country_code           239
# Country                  0
# WHO_region            4302
# New_cases            18491
# Cumulative_cases         0
# New_deaths           32404
# Cumulative_deaths        0
# dtype: int64

# %%
#checking for duplicates

data.duplicated().sum()
# Out:
# 0

# %%
#performing summary statistics

data.describe()

#by this we can get all the statistical values of the dataset
# Out:
#           New_cases  Cumulative_cases    New_deaths  Cumulative_deaths
# count  3.886900e+04      5.736000e+04  24956.000000       5.736000e+04
# mean   1.996013e+04      1.780546e+06    282.741946       1.993156e+04
# std    2.713327e+05      7.761003e+06   1215.423478       8.162997e+04
# min   -6.507900e+04      0.000000e+00  -3432.000000       0.000000e+00
# 25%    4.300000e+01      4.029750e+03      4.000000       2.800000e+01
# 50%    3.950000e+02      4.579350e+04     20.000000       5.515000e+02
# 75%    4.009000e+03      5.160230e+05    105.000000       6.885250e+03
# max    4.047548e+07      1.034368e+08  47687.000000       1.192328e+06

# %%
#EDA Exploratory data analysis

plt.figure(figsize = (12,6))
sns.countplot(data = data, x = "Country", order = data['Country'].value_counts().index)
plt.title("Distribution by cases by Country")
plt.show()

# %%
#total cases over time
plt.figure(figsize=(10,6))
sns.lineplot(data = data, x = 'Date_reported', y = 'New_cases', estimator = 'sum')
plt.title("Distribution of cases over time")
plt.show()
#tis is very case sensible
#the ploting should be exactly like as it is in the data set

# %%
#country wise
plt.figure(figsize=(10,6))
sns.lineplot(data = data, x = 'Country_code', y = 'New_cases', estimator = 'sum')
plt.title("Total cases Country wise")
plt.show()
